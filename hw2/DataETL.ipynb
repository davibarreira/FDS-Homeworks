# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
enem = pd.read_csv('./Data/ENEM2015.csv')

# %%
df    = pd.read_csv('./Data/DadosEscolares1996-2015.csv')

# %%
enem
# Out:
#       CODIGO DA ENTIDADE  NUMERO DE PARTICIPANTES  Classificacao
# 0               35000139                      142              1
# 1               35000140                       79              1
# 2               35000267                      131              2
# 3               35000280                      146              1
# 4               35000334                       95              1
# 5               35000413                      100              1
# 6               35000486                      146              3
# 7               35000553                      172              2
# 8               35000620                       81              2
# 9               35000668                       44              1
# 10              35000673                       97              1
# 11              35000711                       32              2
# 12              35000848                      147              2
# ...

# %%
pd.merge(enem,df,how='left',right_on='CODMEC',left_on='CODIGO DA ENTIDADE')
# Out:
#        CODIGO DA ENTIDADE  NUMERO DE PARTICIPANTES  Classificacao      CODMEC  \
# 0                35000139                      142              1  35000139.0
# 1                35000139                      142              1  35000139.0
# 2                35000139                      142              1  35000139.0
# 3                35000139                      142              1  35000139.0
# 4                35000139                      142              1  35000139.0
# 5                35000139                      142              1  35000139.0
# 6                35000139                      142              1  35000139.0
# 7                35000139                      142              1  35000139.0
# 8                35000139                      142              1  35000139.0
# 9                35000139                      142              1  35000139.0
# 10               35000139                      142              1  35000139.0
# ...

# %%
ls ./Data/
# Out:
#  DadosEscolares1996-2015.csv*                  ENEM2015.csv*
#  DadosEscolares1996-2015-dicionario.xlsx*      ESC2013_RMSP_CEM.csv*
#  dicionario-RendimentoEscolar2000-2015.xlsx*   RendimentoEscolar2000-2015.csv*
# 'Dicion†rio Base Escolas 2013 - CEM.pdf'*
