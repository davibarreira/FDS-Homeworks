# %%
from scrape_scholar import scrape

# %%
scrape('Evandro Parente')
# Out:
# [{'title': 'An object-oriented framework for finite element programming',
#   'authors': ['LF Martha', 'E Parente Jr']},
#  {'title': 'Improvement of semi‐analytical design sensitivities of non‐linear structures using equilibrium relations',
#   'authors': ['E Parente Jr', 'LE Vaz']},
#  {'title': 'A hybrid shared/distributed memory parallel genetic algorithm for optimization of laminate composites',
#   'authors': ['I Rocha', 'E Parente Jr', 'AMC Melo']},
#  {'title': 'An OOP class organization for materially nonlinear finite element analysis',
#   'authors': ['LF Martha',
#    'IFM Menezes',
#    'EN Lages',
#    'E Parente Jr',
#    'RLS Pitangueira']},
#  {'title': 'Finite element modeling of flexible pavements',
#   'authors': ['ÁS de Holanda',
#    'EP Junior',
#    'TDP de Araújo',
#    'LTB de Melo',
#    'FE Junior']},
#  {'title': 'Optimization of composite catenary risers',
#   'authors': ['RF da Silva',
#    'FAF Teófilo',
#    'E Parente Jr',
#    'AMC de Melo',
# ...
